# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Daniel-534/MecanicaCeleste/blob/main/Clases/Clase20260427.ipynb)

# %% [markdown]
# # Ecuación de kepler

# %%
# !pip install pymcel -Uq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 47.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 64.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 38.4 MB/s eta 0:00:00

# %%
import numpy as np
import matplotlib.pyplot as plt
import pymcel as pc
# Out:
# Bienvenido a PyMCel v0.9.18 ¡al infinito y más allá!

# %%
deg = np.pi/180

# %%
e = 0.1911663355386932
a =	0.9223803173917017 * pc.constantes.au
q = 0.7460522521429133 * pc.constantes.au
i = 3.340958441017069 * deg
node = 203.8996515621043 * deg
peri  = 126.6728325163065 * deg
tp = 2461042.918242006079 * 86400# Fecha juliana
mu = pc.constantes.mu_sun # mu del sistema solar

# %% [markdown]
# Variables derivadas

# %%
h = np.sqrt(mu*a*(1-e**2))
b = a * np.sqrt(1-e**2)

# %% [markdown]
# ¿Cuál es el tiempo?

# %%
from astropy.time import Time

# %%
t = Time("2029-04-13 18:52:00", scale="tdb").jd * 86400
t
# Out:
# np.float64(212737560720.0)

# %% [markdown]
# Escribir la ecuación en la forma $f(E) = 0$

# %%
def ecuacion_kepler(E):
    funcion = E - e * np.sin(E) - h / (a * b) * (t - tp)
    return funcion

# %% [markdown]
# Resolver la ecuación

# %%
from scipy.optimize import newton

# %%
newton(ecuacion_kepler, 0)
# Out:
# np.float64(23.081594014937842)
