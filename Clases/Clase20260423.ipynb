# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Daniel-534/MecanicaCeleste/blob/main/Clases/Clase20260423.ipynb)

# %%
import numpy as np

# %%
p = 3; e=0.3
q = p/(1+e)
a = q/(1-e)
c = a-q
b = np.sqrt(a*p)

# %%
print(b)
# Out:
# 3.144854510165755

# %%
-0.989-3.2
# Out:
# -4.189
