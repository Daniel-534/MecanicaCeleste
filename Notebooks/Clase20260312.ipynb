# %%
# !pip install rebound -Uq

# %%
import pymcel as pc
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
# Out:
# Bienvenido a PyMCel v0.9.17 ¡al infinito y más allá!

# %%
sistema = [
    dict(m=1,r=[0,0,0],v=[0,0,0]),
    dict(m=1,r=[-1,0,0],v=[0,1.0,0.5]),
    dict(m=0.1,r=[1,0,0],v=[0,-0.1,0])
]

# %%
ts = np.linspace(0,5,1000)
rs

# %% [markdown]
# **NOTA:** Tuve problemas con VS Code. Después hago las exploraciones con tres cuerpos e integración  actualizo el repositorio.
